# %%
# Paso 1: Importación de Librerías
import os
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
from transformers import BertTokenizer, BertModel
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import euclidean_distances

# %%
# Paso 2: Cargar el Modelo BERT
tokenizer = BertTokenizer.from_pretrained('dccuchile/bert-base-spanish-wwm-uncased')
model = BertModel.from_pretrained('dccuchile/bert-base-spanish-wwm-uncased')
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-uncased and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Paso 3: Función para Obtener Embeddings de BERT
def bert_embeddings(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
    outputs = model(**inputs)
    # Tomar la media a lo largo de la dimensión de la secuencia para reducir a 2D
    embeddings = outputs.last_hidden_state.mean(dim=1).detach().numpy()
    return embeddings

# %%
# Paso 4: Reemplazo del Código de Chunking
def load_documents(file_paths):
    documents = []
    doc_names = []
    for name, path in file_paths.items():
        with open(path, 'r', encoding='utf-8') as file:
            content = file.read()
            doc = {'page_content': content}
            documents.append(doc)
            doc_names.append(name)
    return documents, doc_names

def split_text(documents):
    chunk_size = 500
    chunk_overlap = 60
    chunks = []
    doc_indices = []
    for i, doc in enumerate(documents):
        content = doc['page_content']
        start = 0
        while start < len(content):
            end = start + chunk_size
            if end > len(content):
                end = len(content)
            chunks.append({'page_content': content[start:end]})
            start += (chunk_size - chunk_overlap)
            doc_indices.append(i)
    print(f"Split {len(documents)} documents into {len(chunks)} chunks.")
    return chunks, doc_indices

# Función para reducir el tamaño del texto en el hover y permitir saltos de línea
def format_chunk(chunk, max_length=50):
    words = chunk.split()
    formatted_chunk = ""
    line_length = 0
    for word in words:
        if line_length + len(word) <= max_length:
            formatted_chunk += word + " "
            line_length += len(word) + 1
        else:
            formatted_chunk += "<br>" + word + " "
            line_length = len(word) + 1
    return formatted_chunk

# Función para encontrar los chunks más similares a las preguntas
def find_most_similar_chunks(question_embeddings, tfidf_matrix, top_k=3):
    similarities = cosine_similarity(question_embeddings, tfidf_matrix)
    top_indices = similarities.argsort(axis=1)[:, -top_k:]
    top_similarities = np.array([similarities[i, indices] for i, indices in enumerate(top_indices)])
    return top_indices, top_similarities

# %%
# Paso 5: Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Paso 6: Cargar Documentos
file_paths = {
    "Auditorias": "/content/drive/MyDrive/PROYECTO TFM (team NF-AI)/CODIGO/txt/auditorias.txt",
    "Ausentismo": "/content/drive/MyDrive/PROYECTO TFM (team NF-AI)/CODIGO/txt/ausentismo.txt",
    "Estructura Organizativa": "/content/drive/MyDrive/PROYECTO TFM (team NF-AI)/CODIGO/txt/estructura organizativa.txt",
    "Riesgos": "/content/drive/MyDrive/PROYECTO TFM (team NF-AI)/CODIGO/txt/riesgos.txt",
    "Informacion": "/content/drive/MyDrive/PROYECTO TFM (team NF-AI)/CODIGO/txt/información.txt",
    "Emergencia": "/content/drive/MyDrive/PROYECTO TFM (team NF-AI)/CODIGO/txt/emergencia.txt"
}

# %%
# Paso 7: Lista de Preguntas
questions = [
    "¿Cómo se diferencia la ubicación física de la operativa?",  # Manual Estructura Organizativa pág. 60 y 73.
    "¿Qué información se incluye en el informe de la evaluación de riesgos que ofrece la plataforma y cuál es su utilidad para la gestión de riesgos en la empresa?",  # Manual Identificación y Evaluación de Riesgos (IER); pág. 24 - 26.
    "¿Hay indicadores relativos al cumplimiento de normas?",  # Manual Auditorías pág. 16 17 30 y 31.
    "¿Qué papel juega la estructura organizativa en la funcionalidad general de la plataforma y cómo interactúa con otros módulos?",  # Manual Estructura Organizativa
    "¿Qué permite realizar la evaluación de riesgos?",  # Manual Identificación y Evaluación de Riesgos (IER)
    "¿Qué tipo de documentos se pueden almacenar y compartir en el espacio denominado 'Documentos' y cuál es su importancia dentro del contexto de la gestión empresarial en la plataforma?",  # Manual del Repositorio documental
    "¿Se pueden llevar a cabo auditorías internas?",  # Manual Auditorías
    "¿Cuál es la tasa de adopción de esta plataforma en el mercado?",  # Pregunta que no se puede resolver con los manuales
    "¿Cómo se compara esta plataforma con otras soluciones de gestión de SST?",  # Pregunta que no se puede resolver con los manuales
    "¿Qué día hará mañana?"  # Pregunta totalmente fuera del contexto
]

# %%
documents, doc_names = load_documents(file_paths)
chunks, doc_indices = split_text(documents)

all_chunks = [chunk['page_content'] for chunk in chunks]
chunk_to_manual = [doc_names[i] for i in doc_indices]
# Out:
# Split 6 documents into 209 chunks.

# %%
chunk_embeddings = np.array([bert_embeddings(chunk) for chunk in all_chunks]).squeeze()
question_embeddings = np.array([bert_embeddings(question) for question in questions])
# Out:
# Shape of chunk_embeddings: (209, 768)
# Shape of question_embeddings: (10, 1, 768)

# %%
# Verificar y ajustar la forma de los embeddings
if len(chunk_embeddings.shape) == 3:
    chunk_embeddings = chunk_embeddings.reshape(chunk_embeddings.shape[0], -1)
if len(question_embeddings.shape) == 3:
    question_embeddings = question_embeddings.reshape(question_embeddings.shape[0], -1)

print(f"Shape of chunk_embeddings: {chunk_embeddings.shape}")
print(f"Shape of question_embeddings: {question_embeddings.shape}")
# Out:
# Shape of chunk_embeddings: (209, 768)
# Shape of question_embeddings: (10, 768)

# %%
# Paso 8: Reducción de Dimensionalidad
pca = PCA(n_components=50)
pca_result = pca.fit_transform(chunk_embeddings)

tsne = TSNE(n_components=2, perplexity=40, n_iter=300)
tsne_result = tsne.fit_transform(pca_result)

df = pd.DataFrame(tsne_result, columns=['x', 'y'])
df['manual'] = chunk_to_manual
df['chunk'] = all_chunks

# %% [markdown]
# ### CON euclidean_distances

# %%
# Función get_similar_chunks para usar distancia euclidiana
def get_similar_chunks(question_index, top_k=3):
    distances = euclidean_distances([question_embeddings[question_index]], chunk_embeddings)[0]
    top_indices = distances.argsort()[:top_k]  # Menores distancias
    return [(all_chunks[i], distances[i]) for i in top_indices]

# %%
# Paso 10: Obtener y Mostrar los Chunks Más Similares
for i, question in enumerate(questions):
    print(f"Question: {question}")
    similar_chunks = get_similar_chunks(i)
    for chunk, distance in similar_chunks:
        print(f"Euclidean Distance: {distance}")
        print(f"Chunk: {chunk}")
        print("-" * 50)
# Out:
# Question: ¿Cómo se diferencia la ubicación física de la operativa?
# Euclidean Distance: 12.849054336547852
# Chunk: eacción tipo emergencia   instalación actual reacción frente principal amenaza identificado .
#
# 5   •   Establecer mantener esquema organización interno , confeccionar   equipo respuesta intervención frente emergencia .   •   minimizar pérdida material ambiental derivado   situación emergencia poder presentar .   •   Minimizar riesgo desencadenar emergencia , control   .    •   Restablecer ritmo normal trabajo brevedad .   ¿ SIMULACRO ?
#
# simulacro ensayo ejercicio adiestramiento práctico actuar c
# --------------------------------------------------
# Euclidean Distance: 12.87404727935791
# Chunk: distinto ubicación   empresa ( ubicación físico operativo ) .      herencia funcionar distinto depender provenir ubicación físico   operativo . caso , herencia seguir dirección “ abajo ” .   , nivel alto estructura organizativo
#
# nivel alto estructura organizativo nivel bajo .   contrario , caso ubicación operativo , considerar .   ejemplo , trabajador empresa afectar riesgo evaluado :    estructura físico :    •   riesgo evaluado empresa pertenecer .    •   riesgo evaluado centro pertenecer .
# --------------------------------------------------
# Euclidean Distance: 12.896764755249023
# Chunk: Versión   Fecha   Comentarios   Autor   1.0   29/09/2022   Redacción   Núria Zaragoza
#
# Sabentis plataforma gestión especializado ámbito Seguridad Salud   Trabajo adaptado tecnología modelo gestión   prevención .    plataforma distinto tipo auditoría objetivo , figurar   evaluación Estándares Internacionales ( ISO ) Metodología 5s , responder   conjunto norma , requisito procedimiento reflejar imagen sistema   prevención riesgo laboral
#
# sistema   prevención riesgo laboral empresa .
#
# usuario acced
# --------------------------------------------------
# Question: ¿Qué información se incluye en el informe de la evaluación de riesgos que ofrece la plataforma y cuál es su utilidad para la gestión de riesgos en la empresa?
# Euclidean Distance: 11.180837631225586
# Chunk: eliminar riesgo .
#
# 2 . identificación evaluación RIESGOS ( IER )
#
# identificación evaluación riesgo proceso técnico inicial materia seguridad   salud trabajo , basar gestión preventivo empresa .   actividad objetivo analizar elemento componer espacio físico ,   actividad desarrollar estimar valorar   daño producir conjunto factor tiempo determinado , finalmente ,   determinar medida acción
#
# , finalmente ,   determinar medida acción concreto prevenir ocurrencia accidente   trabajo / enfermedad pro
# --------------------------------------------------
# Euclidean Distance: 11.400030136108398
# Chunk: eto prevenir ocurrencia accidente   trabajo / enfermedad profesional .
#
# usuario acceder módulo identificación evaluación riesgo ( IER )   empresa seleccionado contexto , :   •   entrada menú lateral plataforma .   •   cardboard “ Identificación Evaluación Riesgos ” .   clicar menú lateral cardboard , usuario redirigir Home   módulo , visualizar siguiente cardboard :
#
# usuario ingresar cardboard “ Evaluaciones ” visualizar listado evaluación   empresa . abierto cerrado .   campo formulario marcado
# --------------------------------------------------
# Euclidean Distance: 11.440078735351562
# Chunk: ades   Profesionales Accidentes Trabajo ) Medidas Preventivas / Correctivas .    1 .   previamente verificar existir registro contingencia módulo   ausentismo . registro aparecer pestaña Contingencias Asociadas ,   módulo IER , añadir Medidas Preventivas / Correctoras existente .   documento
#
# usuario acceder pestaño Documentos visualizar listado informe generado tal   : documento evaluación riesgo notificación riesgo trabajador .   pantalla usuario generar n informe formato   independiente evalu
# --------------------------------------------------
# Question: ¿Hay indicadores relativos al cumplimiento de normas?
# Euclidean Distance: 16.754243850708008
# Chunk: r reconocimiento internacional objetivo ayudar empresa   establecer nivel homogeneidad relación gestión , prestación   servicio desarrollo producto industria .    •   ISO 45001 : Sistemas gestión SST .   •   ISO 14001 : Sistemas gestión ambiente .   •   ISO 9001 : Sistemas gestión calidad .   •   ISO 39001 : Sistemas
#
# Sistemas gestión calidad .   •   ISO 39001 : Sistemas gestión seguridad vial .   •   ISO 37001 : Sistemas gestión antisoborno .   •   ISO 22301 : Sistemas gestión continuidad negoc
# --------------------------------------------------
# Euclidean Distance: 16.822723388671875
# Chunk: Fecha adquisición   •   Cuestionario técnico campo :   •   ¿ disponer marcado CE ?   •   ¿ disponer puesta conformidad ?   •
#
# marcado CE ?   •   ¿ disponer puesta conformidad ?   •   ¿ disponer adaptación / mejor ?   •   ¿ propiedad empresa externo ?
#
# 86   •   Empresa externo ( función respuesta pregunta ( ) )   •   ¿ requerir formación específico ?   •   ¿ requerir mantenimiento ?   2 . tipo AM AGENTE QUÍMICO : añadir campo :    •   Nombre agente químico – Número CAS : Muestra listado agente qu
# --------------------------------------------------
# Euclidean Distance: 16.92927360534668
# Chunk: mizar riesgo expuesto puesto   trabajo característica personal . listado informativo   siguiente opción : buscador , filtrar , descargar listado paginado .   •   listado
#
# descargar listado paginado .   •   listado Entregas EPP realizado mostrar entrega EPP   realizar trabajador . listado siguiente   opción : buscador , filtrar , descargar listado , paginado acción abrir   pantalla lateral visualizar forma informativo dato relativo   entrega . entrega vigente , vigente devolución parcial ,   devo
# --------------------------------------------------
# Question: ¿Qué papel juega la estructura organizativa en la funcionalidad general de la plataforma y cómo interactúa con otros módulos?
# Euclidean Distance: 11.933197021484375
# Chunk: rmitir definir obra construcción distinto tipo magnitud , rol   unidad productivo ( empresa principal
#
# rol   unidad productivo ( empresa principal contratista , , centro   ) fecha inicio .    ▪   Itinerante : referencia unidad productivo emplazamiento   fijo duración , vehículo feria .
#
# 3 . home estructura organizativo   usuario acceder módulo Estructura Organizativa ( EO ) , opción :   •   entrada menú lateral .   •   cardboard “ Estructura Organizativa ” .
#
# visualizar cardboard entrada funcion
# --------------------------------------------------
# Euclidean Distance: 12.65270709991455
# Chunk: ctura Organizativa ” .
#
# visualizar cardboard entrada funcionalidad módulo :   •   Empresas   •   Centros trabajo   •   Ocupaciones   •   Lugares trabajo   •   Puestos trabajo   •   Trabajadores   •   Ubicaciones libre físico   •   Ubicaciones libre operativo   •   Perfiles empresa   •   Agentes material
#
# , visualizar dashboard contener dato estadístico actualizado   automáticamente fecha consulta empresa nivel estructura organizativo ,   georreferenciador centro trabajo .   gráfica mostrar infor
# --------------------------------------------------
# Euclidean Distance: 12.668814659118652
# Chunk: ón reflejar realidad   empresa .   2 . MODELO estructura organizativa : EMPRESA
#
# módulo estructura organizativo permitir definición gestión empresa   plataforma , posibilidad configurar ubicación reflejar realidad   empresa herramienta agilizar navegación creación estructura .    estructura organizativo permitir seleccionar entidad básico ocupación   ( CIUO ) concepción puesto trabajo . puesto trabajo entendido   lugar área ocupado persona
#
# entendido   lugar área ocupado persona organización   d
# --------------------------------------------------
# Question: ¿Qué permite realizar la evaluación de riesgos?
# Euclidean Distance: 12.695690155029297
# Chunk: Fecha adquisición   •   Cuestionario técnico campo :   •   ¿ disponer marcado CE ?   •   ¿ disponer puesta conformidad ?   •
#
# marcado CE ?   •   ¿ disponer puesta conformidad ?   •   ¿ disponer adaptación / mejor ?   •   ¿ propiedad empresa externo ?
#
# 86   •   Empresa externo ( función respuesta pregunta ( ) )   •   ¿ requerir formación específico ?   •   ¿ requerir mantenimiento ?   2 . tipo AM AGENTE QUÍMICO : añadir campo :    •   Nombre agente químico – Número CAS : Muestra listado agente qu
# --------------------------------------------------
# Euclidean Distance: 13.000472068786621
# Chunk: dato DOCUMENTO   contenido   Sabentis plataforma gestión especializado ámbito Seguridad Salud   Trabajo adaptado tecnología modelo gestión   prevención .    plataforma disponer módulo “ Ausentismo ” empresa registrar   accidente trabajo , enfermedad profesional , contingencia común , incapacidad ,   ausencia administrativo permiso , investigación .
#
# 2 . sabentis : MÓDULO AUSENTISMO   usuario acceder módulo “ Ausentismo ” , :   •   entrada menú lateral pantalla .   •   cardboard “ Ausentismo ” pa
# --------------------------------------------------
# Euclidean Distance: 13.157238960266113
# Chunk: io formulario medida ( entendimiento   manual flujo gestión
#
# entendimiento   manual flujo gestión medida ) .
#
# usuario acceder cardboard “ Simulacros emergencias ” visualizar listado simulacro   situación real emergencia producir empresa   :   •   Pendiente evaluar : completar evaluación situado   pestaña registro .   •   Evaluado : evaluación realizado actividad definido .   listado opción : buscador , añadir filtro , paginado , descargar listado ,   botón
#
# añadir filtro , paginado , descargar l
# --------------------------------------------------
# Question: ¿Qué tipo de documentos se pueden almacenar y compartir en el espacio denominado 'Documentos' y cuál es su importancia dentro del contexto de la gestión empresarial en la plataforma?
# Euclidean Distance: 11.251702308654785
# Chunk: rmitir definir obra construcción distinto tipo magnitud , rol   unidad productivo ( empresa principal
#
# rol   unidad productivo ( empresa principal contratista , , centro   ) fecha inicio .    ▪   Itinerante : referencia unidad productivo emplazamiento   fijo duración , vehículo feria .
#
# 3 . home estructura organizativo   usuario acceder módulo Estructura Organizativa ( EO ) , opción :   •   entrada menú lateral .   •   cardboard “ Estructura Organizativa ” .
#
# visualizar cardboard entrada funcion
# --------------------------------------------------
# Euclidean Distance: 11.512863159179688
# Chunk: ctura Organizativa ” .
#
# visualizar cardboard entrada funcionalidad módulo :   •   Empresas   •   Centros trabajo   •   Ocupaciones   •   Lugares trabajo   •   Puestos trabajo   •   Trabajadores   •   Ubicaciones libre físico   •   Ubicaciones libre operativo   •   Perfiles empresa   •   Agentes material
#
# , visualizar dashboard contener dato estadístico actualizado   automáticamente fecha consulta empresa nivel estructura organizativo ,   georreferenciador centro trabajo .   gráfica mostrar infor
# --------------------------------------------------
# Euclidean Distance: 11.584246635437012
# Chunk: ismo funcionalidad :   •   Ficheros cargado pregunta Audit / Inspecciones : tag mostrado   preguntar carguir fichero .   •   Ficheros carguir home principal : tag mostrado pregunta   carguir fichero .   •   Ficheros subir medida : tag mostrado “ Medida control ” .
#
# documento tipo informe ( Informe plan emergencia , informe inspección , etc )   generado plataforma predeterminado Origen Internos ,   mostrar información columna fecha vigencia , campo completar   acceder acción Editar .   caso empre
# --------------------------------------------------
# Question: ¿Se pueden llevar a cabo auditorías internas?
# Euclidean Distance: 15.646108627319336
# Chunk: r reconocimiento internacional objetivo ayudar empresa   establecer nivel homogeneidad relación gestión , prestación   servicio desarrollo producto industria .    •   ISO 45001 : Sistemas gestión SST .   •   ISO 14001 : Sistemas gestión ambiente .   •   ISO 9001 : Sistemas gestión calidad .   •   ISO 39001 : Sistemas
#
# Sistemas gestión calidad .   •   ISO 39001 : Sistemas gestión seguridad vial .   •   ISO 37001 : Sistemas gestión antisoborno .   •   ISO 22301 : Sistemas gestión continuidad negoc
# --------------------------------------------------
# Euclidean Distance: 15.67667007446289
# Chunk: ganización respuesta emergencia .   •   capacitación personal organización .   •   entrenamiento personal respuesta frente emergencia .   •   suficiencia idoneidad
#
# frente emergencia .   •   suficiencia idoneidad medio recurso asignado .
#
# 6   2 . sabentis : módulo plan emergencia   usuario acceder módulo “ Planes emergencia ” , :    •   entrada menú lateral plataforma .   •   cardboard “ Planes emergencia ” .   7   visualizar dashboard contener dato estadístico , gráfica mostrar   información :
#
# --------------------------------------------------
# Euclidean Distance: 15.709331512451172
# Chunk: ades   Profesionales Accidentes Trabajo ) Medidas Preventivas / Correctivas .    1 .   previamente verificar existir registro contingencia módulo   ausentismo . registro aparecer pestaña Contingencias Asociadas ,   módulo IER , añadir Medidas Preventivas / Correctoras existente .   documento
#
# usuario acceder pestaño Documentos visualizar listado informe generado tal   : documento evaluación riesgo notificación riesgo trabajador .   pantalla usuario generar n informe formato   independiente evalu
# --------------------------------------------------
# Question: ¿Cuál es la tasa de adopción de esta plataforma en el mercado?
# Euclidean Distance: 12.966968536376953
# Chunk:  centro trabajo mitigar reducir nivel riesgo   amenaza evaluada . medida generado sistema depender   respuesta momento evaluación , :   •   Pendiente planificar : medida generar respuesta .   •   Pendiente evidencia : medida generar
#
# •   Pendiente evidencia : medida generar respuesta   APLICA .   listado opción : buscador , añadir filtro , descargar listado , paginado ,   botón añadir medida redirigir formulario medida , acción :   •   Editar : permitir acceder formulario medida gestión . (   en
# --------------------------------------------------
# Euclidean Distance: 13.068520545959473
# Chunk: io formulario medida ( entendimiento   manual flujo gestión
#
# entendimiento   manual flujo gestión medida ) .
#
# usuario acceder cardboard “ Simulacros emergencias ” visualizar listado simulacro   situación real emergencia producir empresa   :   •   Pendiente evaluar : completar evaluación situado   pestaña registro .   •   Evaluado : evaluación realizado actividad definido .   listado opción : buscador , añadir filtro , paginado , descargar listado ,   botón
#
# añadir filtro , paginado , descargar l
# --------------------------------------------------
# Euclidean Distance: 13.127352714538574
# Chunk: eto prevenir ocurrencia accidente   trabajo / enfermedad profesional .
#
# usuario acceder módulo identificación evaluación riesgo ( IER )   empresa seleccionado contexto , :   •   entrada menú lateral plataforma .   •   cardboard “ Identificación Evaluación Riesgos ” .   clicar menú lateral cardboard , usuario redirigir Home   módulo , visualizar siguiente cardboard :
#
# usuario ingresar cardboard “ Evaluaciones ” visualizar listado evaluación   empresa . abierto cerrado .   campo formulario marcado
# --------------------------------------------------
# Question: ¿Cómo se compara esta plataforma con otras soluciones de gestión de SST?
# Euclidean Distance: 12.480120658874512
# Chunk: Versión   Fecha   Comentarios   Autor   1.0   29/09/2022   Redacción   Núria Zaragoza
#
# Sabentis plataforma gestión especializado ámbito Seguridad Salud   Trabajo adaptado tecnología modelo gestión   prevención .    plataforma distinto tipo auditoría objetivo , figurar   evaluación Estándares Internacionales ( ISO ) Metodología 5s , responder   conjunto norma , requisito procedimiento reflejar imagen sistema   prevención riesgo laboral
#
# sistema   prevención riesgo laboral empresa .
#
# usuario acced
# --------------------------------------------------
# Euclidean Distance: 12.482941627502441
# Chunk: rmitir definir obra construcción distinto tipo magnitud , rol   unidad productivo ( empresa principal
#
# rol   unidad productivo ( empresa principal contratista , , centro   ) fecha inicio .    ▪   Itinerante : referencia unidad productivo emplazamiento   fijo duración , vehículo feria .
#
# 3 . home estructura organizativo   usuario acceder módulo Estructura Organizativa ( EO ) , opción :   •   entrada menú lateral .   •   cardboard “ Estructura Organizativa ” .
#
# visualizar cardboard entrada funcion
# --------------------------------------------------
# Euclidean Distance: 12.499204635620117
# Chunk: dato DOCUMENTO   contenido   Sabentis plataforma gestión especializado ámbito Seguridad Salud   Trabajo adaptado tecnología modelo gestión   prevención .    plataforma disponer módulo “ Ausentismo ” empresa registrar   accidente trabajo , enfermedad profesional , contingencia común , incapacidad ,   ausencia administrativo permiso , investigación .
#
# 2 . sabentis : MÓDULO AUSENTISMO   usuario acceder módulo “ Ausentismo ” , :   •   entrada menú lateral pantalla .   •   cardboard “ Ausentismo ” pa
# --------------------------------------------------
# Question: ¿Qué día hará mañana?
# Euclidean Distance: 15.528267860412598
# Chunk: rivial , Tolerable , Moderado ,   Importante Intolerable ) . gráfica descargar .   medida tipo   medida   Gráfica dato circular determinar número medida   jerarquía control . gráfica descargar .   medida   Gráfica dato circular determinar número medida
#
# circular determinar número medida   gestión . gráfica descargar .   vencimiento   medida   Gráfica línea vencimiento fecha medida 6 mes ,   área tipo vencimiento , ( validación , implementación ,   verificación ) . gráfica descargar .
#
# 7   •
# --------------------------------------------------
# Euclidean Distance: 15.632990837097168
# Chunk: mentación ,   verificación ) . gráfica descargar .
#
# 7   •   Datos evaluación : Redirige ficha evaluación .   •   evaluación : Redirige pestaña “ Evaluación ubicación ” .   •   medida control : Redirige pestaña “ Medidas preventivo / correctiva ” .   •   eliminar evaluación : permitir eliminar registro .
#
# pestaño Datos evaluación habilitar botón “ Cerrar evaluación ”   evaluación .    creado registro evaluación , habilitar pestaña :     •   Evaluación ubicación    •   Medidas preventivo / correct
# --------------------------------------------------
# Euclidean Distance: 15.78679084777832
# Chunk: 22   Actualización   Mercedes León Chele   Versión 1.2   15/06/2022   Actualización   Andrea Alonso Almecija   Versión 2.0   13/10/2022   Actualización   Mercedes León Chele   contenido
#
# contenido   Sabentis plataforma gestión especializado ámbito Seguridad Salud   Trabajo adaptado tecnología modelo gestión   prevención .     módulo Estructura Organizativa permitir definición gestión empresa   plataforma , posibilidad configurar ubicación reflejar realidad   empresa .   2 . MODELO estructura org
# --------------------------------------------------

# %% [markdown]
# ### CON cosine_similartity

# %%
# Función get_similar_chunks para usar similitud del coseno
def get_similar_chunks(question_index, top_k=3):
    similarities = cosine_similarity([question_embeddings[question_index]], chunk_embeddings)[0]
    top_indices = similarities.argsort()[-top_k:][::-1]
    return [(all_chunks[i], similarities[i]) for i in top_indices]

# Paso 10: Obtener y Mostrar los Chunks Más Similares
for i, question in enumerate(questions):
    print(f"Question: {question}")
    similar_chunks = get_similar_chunks(i)
    for chunk, similarity in similar_chunks:
        print(f"Cosine Similarity: {similarity}")
        print(f"Chunk: {chunk}")
        print("-" * 50)
# Out:
# Question: ¿Cómo se diferencia la ubicación física de la operativa?
# Cosine Similarity: 0.6616424918174744
# Chunk:
# simulacro ensayo ejercicio adiestramiento práctico actuar caso   emergencia , cuyo realización permitir comprobar real adecuación   previsto Plan emergencia organización necesidad existente servir ,   mayoría ocasión , identificar cabo actividad mejora   procedimiento establecido medio instalación .   simulacro emergencia ejercicio práctico
#
# simulacro emergencia ejercicio práctico implicar participación   personal caso involucrar medio externo poder   bombero , protección civil , policía person
# --------------------------------------------------
# Cosine Similarity: 0.6599546670913696
# Chunk: Versión   Fecha   Comentarios   Autor   1.0   29/09/2022   Redacción   Núria Zaragoza
#
# Sabentis plataforma gestión especializado ámbito Seguridad Salud   Trabajo adaptado tecnología modelo gestión   prevención .    plataforma distinto tipo auditoría objetivo , figurar   evaluación Estándares Internacionales ( ISO ) Metodología 5s , responder   conjunto norma , requisito procedimiento reflejar imagen sistema   prevención riesgo laboral
#
# sistema   prevención riesgo laboral empresa .
#
# usuario acced
# --------------------------------------------------
# Cosine Similarity: 0.6539250016212463
# Chunk:  externo poder   bombero , protección civil , policía personal sanitario .    realización periódico simulacro , mínimo año , pretender   cabo activación plan emergencia previo aviso momento   comprobar resultado participación eficiente
#
# resultado participación eficiente grupo trabajador   implicado , crear hábito respuesta organizado operativo   adiestramiento práctico .   objetivo simulacro verificación comprobación :   •   eficacia organización respuesta emergencia .   •   capacitación persona
# --------------------------------------------------
# Question: ¿Qué información se incluye en el informe de la evaluación de riesgos que ofrece la plataforma y cuál es su utilidad para la gestión de riesgos en la empresa?
# Cosine Similarity: 0.7215590476989746
# Chunk: eliminar riesgo .
#
# 2 . identificación evaluación RIESGOS ( IER )
#
# identificación evaluación riesgo proceso técnico inicial materia seguridad   salud trabajo , basar gestión preventivo empresa .   actividad objetivo analizar elemento componer espacio físico ,   actividad desarrollar estimar valorar   daño producir conjunto factor tiempo determinado , finalmente ,   determinar medida acción
#
# , finalmente ,   determinar medida acción concreto prevenir ocurrencia accidente   trabajo / enfermedad pro
# --------------------------------------------------
# Cosine Similarity: 0.7048431038856506
# Chunk:    •   riesgo evaluado subtarea tarea punto .
#
# herencia visualizar listado riesgo vista trabajador , “ Riesgos   persona ” “ Riesgos ubicación ” .
#
# usuario acceder cardboard “ Configuración ” , configuración   metodología evaluación riesgo utilizar empresa .   seleccionar metodología , aplicar ubicación estructura   organizativo . usuario cerciorar metodología seleccionado correcto ,   existir registro evaluación , cambiar . guardar   configuración , consideración
#
#   configuración , consideració
# --------------------------------------------------
# Cosine Similarity: 0.7002068758010864
# Chunk: ades   Profesionales Accidentes Trabajo ) Medidas Preventivas / Correctivas .    1 .   previamente verificar existir registro contingencia módulo   ausentismo . registro aparecer pestaña Contingencias Asociadas ,   módulo IER , añadir Medidas Preventivas / Correctoras existente .   documento
#
# usuario acceder pestaño Documentos visualizar listado informe generado tal   : documento evaluación riesgo notificación riesgo trabajador .   pantalla usuario generar n informe formato   independiente evalu
# --------------------------------------------------
# Question: ¿Hay indicadores relativos al cumplimiento de normas?
# Cosine Similarity: 0.45250922441482544
# Chunk: Fecha adquisición   •   Cuestionario técnico campo :   •   ¿ disponer marcado CE ?   •   ¿ disponer puesta conformidad ?   •
#
# marcado CE ?   •   ¿ disponer puesta conformidad ?   •   ¿ disponer adaptación / mejor ?   •   ¿ propiedad empresa externo ?
#
# 86   •   Empresa externo ( función respuesta pregunta ( ) )   •   ¿ requerir formación específico ?   •   ¿ requerir mantenimiento ?   2 . tipo AM AGENTE QUÍMICO : añadir campo :    •   Nombre agente químico – Número CAS : Muestra listado agente qu
# --------------------------------------------------
# Cosine Similarity: 0.4520275294780731
# Chunk: ades   Profesionales Accidentes Trabajo ) Medidas Preventivas / Correctivas .    1 .   previamente verificar existir registro contingencia módulo   ausentismo . registro aparecer pestaña Contingencias Asociadas ,   módulo IER , añadir Medidas Preventivas / Correctoras existente .   documento
#
# usuario acceder pestaño Documentos visualizar listado informe generado tal   : documento evaluación riesgo notificación riesgo trabajador .   pantalla usuario generar n informe formato   independiente evalu
# --------------------------------------------------
# Cosine Similarity: 0.442153662443161
# Chunk: permitir enviar correo directamente trabajador .   •   Eliminar : permitir eliminar registro trabajador .
#
# PESTAÑA documento   pestaña usuario visualizar listado documento disponible nivel   empresa , documento “ vigente ” “ expirado ” .   documento cargado pestaña visualizar listado repositorio   documental . , documento estructura organizativo , defecto
#
# 15   añadir tags predefinido ( entendimiento manual repositorio   documental ) .   listado siguiente opción : buscador , filtrar , paginado ,
# --------------------------------------------------
# Question: ¿Qué papel juega la estructura organizativa en la funcionalidad general de la plataforma y cómo interactúa con otros módulos?
# Cosine Similarity: 0.6799746751785278
# Chunk: rmitir definir obra construcción distinto tipo magnitud , rol   unidad productivo ( empresa principal
#
# rol   unidad productivo ( empresa principal contratista , , centro   ) fecha inicio .    ▪   Itinerante : referencia unidad productivo emplazamiento   fijo duración , vehículo feria .
#
# 3 . home estructura organizativo   usuario acceder módulo Estructura Organizativa ( EO ) , opción :   •   entrada menú lateral .   •   cardboard “ Estructura Organizativa ” .
#
# visualizar cardboard entrada funcion
# --------------------------------------------------
# Cosine Similarity: 0.6535772085189819
# Chunk: ctura Organizativa ” .
#
# visualizar cardboard entrada funcionalidad módulo :   •   Empresas   •   Centros trabajo   •   Ocupaciones   •   Lugares trabajo   •   Puestos trabajo   •   Trabajadores   •   Ubicaciones libre físico   •   Ubicaciones libre operativo   •   Perfiles empresa   •   Agentes material
#
# , visualizar dashboard contener dato estadístico actualizado   automáticamente fecha consulta empresa nivel estructura organizativo ,   georreferenciador centro trabajo .   gráfica mostrar infor
# --------------------------------------------------
# Cosine Similarity: 0.6465690732002258
# Chunk: ón reflejar realidad   empresa .   2 . MODELO estructura organizativa : EMPRESA
#
# módulo estructura organizativo permitir definición gestión empresa   plataforma , posibilidad configurar ubicación reflejar realidad   empresa herramienta agilizar navegación creación estructura .    estructura organizativo permitir seleccionar entidad básico ocupación   ( CIUO ) concepción puesto trabajo . puesto trabajo entendido   lugar área ocupado persona
#
# entendido   lugar área ocupado persona organización   d
# --------------------------------------------------
# Question: ¿Qué permite realizar la evaluación de riesgos?
# Cosine Similarity: 0.6701197624206543
# Chunk: Fecha adquisición   •   Cuestionario técnico campo :   •   ¿ disponer marcado CE ?   •   ¿ disponer puesta conformidad ?   •
#
# marcado CE ?   •   ¿ disponer puesta conformidad ?   •   ¿ disponer adaptación / mejor ?   •   ¿ propiedad empresa externo ?
#
# 86   •   Empresa externo ( función respuesta pregunta ( ) )   •   ¿ requerir formación específico ?   •   ¿ requerir mantenimiento ?   2 . tipo AM AGENTE QUÍMICO : añadir campo :    •   Nombre agente químico – Número CAS : Muestra listado agente qu
# --------------------------------------------------
# Cosine Similarity: 0.6566294431686401
# Chunk: dato DOCUMENTO   contenido   Sabentis plataforma gestión especializado ámbito Seguridad Salud   Trabajo adaptado tecnología modelo gestión   prevención .    plataforma disponer módulo “ Ausentismo ” empresa registrar   accidente trabajo , enfermedad profesional , contingencia común , incapacidad ,   ausencia administrativo permiso , investigación .
#
# 2 . sabentis : MÓDULO AUSENTISMO   usuario acceder módulo “ Ausentismo ” , :   •   entrada menú lateral pantalla .   •   cardboard “ Ausentismo ” pa
# --------------------------------------------------
# Cosine Similarity: 0.6516707539558411
# Chunk: eliminar riesgo .
#
# 2 . identificación evaluación RIESGOS ( IER )
#
# identificación evaluación riesgo proceso técnico inicial materia seguridad   salud trabajo , basar gestión preventivo empresa .   actividad objetivo analizar elemento componer espacio físico ,   actividad desarrollar estimar valorar   daño producir conjunto factor tiempo determinado , finalmente ,   determinar medida acción
#
# , finalmente ,   determinar medida acción concreto prevenir ocurrencia accidente   trabajo / enfermedad pro
# --------------------------------------------------
# Question: ¿Qué tipo de documentos se pueden almacenar y compartir en el espacio denominado 'Documentos' y cuál es su importancia dentro del contexto de la gestión empresarial en la plataforma?
# Cosine Similarity: 0.6997672319412231
# Chunk: rmitir definir obra construcción distinto tipo magnitud , rol   unidad productivo ( empresa principal
#
# rol   unidad productivo ( empresa principal contratista , , centro   ) fecha inicio .    ▪   Itinerante : referencia unidad productivo emplazamiento   fijo duración , vehículo feria .
#
# 3 . home estructura organizativo   usuario acceder módulo Estructura Organizativa ( EO ) , opción :   •   entrada menú lateral .   •   cardboard “ Estructura Organizativa ” .
#
# visualizar cardboard entrada funcion
# --------------------------------------------------
# Cosine Similarity: 0.6993719339370728
# Chunk: ctura Organizativa ” .
#
# visualizar cardboard entrada funcionalidad módulo :   •   Empresas   •   Centros trabajo   •   Ocupaciones   •   Lugares trabajo   •   Puestos trabajo   •   Trabajadores   •   Ubicaciones libre físico   •   Ubicaciones libre operativo   •   Perfiles empresa   •   Agentes material
#
# , visualizar dashboard contener dato estadístico actualizado   automáticamente fecha consulta empresa nivel estructura organizativo ,   georreferenciador centro trabajo .   gráfica mostrar infor
# --------------------------------------------------
# Cosine Similarity: 0.6856027841567993
# Chunk:    ¿ disponer marcado CE ?   •   ¿ disponer puesta conformidad ?   •   ¿ propiedad empresa externo ?   •   Empresa externo   •   ¿ requerir formación específico ?   •   ¿ Circula vía público ?
#
# 88   •   Matrícula   •   ¿ requerir mantenimiento ?   acceder pestaña usuario visualiza registrar adaptación   agente material . listado contener opción búsqueda , filtrado ,   paginado , botón “ ” redirigir formulario creación adaptación   acción editar eliminar . campo formulario marcado * carácter   ob
# --------------------------------------------------
# Question: ¿Se pueden llevar a cabo auditorías internas?
# Cosine Similarity: 0.516964316368103
# Chunk: ades   Profesionales Accidentes Trabajo ) Medidas Preventivas / Correctivas .    1 .   previamente verificar existir registro contingencia módulo   ausentismo . registro aparecer pestaña Contingencias Asociadas ,   módulo IER , añadir Medidas Preventivas / Correctoras existente .   documento
#
# usuario acceder pestaño Documentos visualizar listado informe generado tal   : documento evaluación riesgo notificación riesgo trabajador .   pantalla usuario generar n informe formato   independiente evalu
# --------------------------------------------------
# Cosine Similarity: 0.516525387763977
# Chunk:  externo poder   bombero , protección civil , policía personal sanitario .    realización periódico simulacro , mínimo año , pretender   cabo activación plan emergencia previo aviso momento   comprobar resultado participación eficiente
#
# resultado participación eficiente grupo trabajador   implicado , crear hábito respuesta organizado operativo   adiestramiento práctico .   objetivo simulacro verificación comprobación :   •   eficacia organización respuesta emergencia .   •   capacitación persona
# --------------------------------------------------
# Cosine Similarity: 0.5155494213104248
# Chunk:    ¿ disponer marcado CE ?   •   ¿ disponer puesta conformidad ?   •   ¿ propiedad empresa externo ?   •   Empresa externo   •   ¿ requerir formación específico ?   •   ¿ Circula vía público ?
#
# 88   •   Matrícula   •   ¿ requerir mantenimiento ?   acceder pestaña usuario visualiza registrar adaptación   agente material . listado contener opción búsqueda , filtrado ,   paginado , botón “ ” redirigir formulario creación adaptación   acción editar eliminar . campo formulario marcado * carácter   ob
# --------------------------------------------------
# Question: ¿Cuál es la tasa de adopción de esta plataforma en el mercado?
# Cosine Similarity: 0.6452580690383911
# Chunk:  centro trabajo mitigar reducir nivel riesgo   amenaza evaluada . medida generado sistema depender   respuesta momento evaluación , :   •   Pendiente planificar : medida generar respuesta .   •   Pendiente evidencia : medida generar
#
# •   Pendiente evidencia : medida generar respuesta   APLICA .   listado opción : buscador , añadir filtro , descargar listado , paginado ,   botón añadir medida redirigir formulario medida , acción :   •   Editar : permitir acceder formulario medida gestión . (   en
# --------------------------------------------------
# Cosine Similarity: 0.63551265001297
# Chunk: io formulario medida ( entendimiento   manual flujo gestión
#
# entendimiento   manual flujo gestión medida ) .
#
# usuario acceder cardboard “ Simulacros emergencias ” visualizar listado simulacro   situación real emergencia producir empresa   :   •   Pendiente evaluar : completar evaluación situado   pestaña registro .   •   Evaluado : evaluación realizado actividad definido .   listado opción : buscador , añadir filtro , paginado , descargar listado ,   botón
#
# añadir filtro , paginado , descargar l
# --------------------------------------------------
# Cosine Similarity: 0.629194974899292
# Chunk: eto prevenir ocurrencia accidente   trabajo / enfermedad profesional .
#
# usuario acceder módulo identificación evaluación riesgo ( IER )   empresa seleccionado contexto , :   •   entrada menú lateral plataforma .   •   cardboard “ Identificación Evaluación Riesgos ” .   clicar menú lateral cardboard , usuario redirigir Home   módulo , visualizar siguiente cardboard :
#
# usuario ingresar cardboard “ Evaluaciones ” visualizar listado evaluación   empresa . abierto cerrado .   campo formulario marcado
# --------------------------------------------------
# Question: ¿Cómo se compara esta plataforma con otras soluciones de gestión de SST?
# Cosine Similarity: 0.6693853735923767
# Chunk: Versión   Fecha   Comentarios   Autor   1.0   29/09/2022   Redacción   Núria Zaragoza
#
# Sabentis plataforma gestión especializado ámbito Seguridad Salud   Trabajo adaptado tecnología modelo gestión   prevención .    plataforma distinto tipo auditoría objetivo , figurar   evaluación Estándares Internacionales ( ISO ) Metodología 5s , responder   conjunto norma , requisito procedimiento reflejar imagen sistema   prevención riesgo laboral
#
# sistema   prevención riesgo laboral empresa .
#
# usuario acced
# --------------------------------------------------
# Cosine Similarity: 0.6655099391937256
# Chunk: sistema   prevención riesgo laboral empresa .
#
# usuario acceder módulo Auditorías :   •   entrada menú lateral plataforma .   •   cardboard “ Auditorías ” panel principal . requerir empresa   contexto .   5   •   Diagnósticos ISO .   •   Metodología 5s.   •   Planificación ejecución medida .   •   Comparativa estudio .   , visualizar dashboard contener dato estadístico . gráfico   descargar mostrar información :
#
# Gráfica   Descripción   conformidad identificado   cumplir vs cumplir   Gráfica circ
# --------------------------------------------------
# Cosine Similarity: 0.6609582901000977
# Chunk: dato DOCUMENTO   contenido   Sabentis plataforma gestión especializado ámbito Seguridad Salud   Trabajo adaptado tecnología modelo gestión   prevención .    plataforma disponer módulo “ Ausentismo ” empresa registrar   accidente trabajo , enfermedad profesional , contingencia común , incapacidad ,   ausencia administrativo permiso , investigación .
#
# 2 . sabentis : MÓDULO AUSENTISMO   usuario acceder módulo “ Ausentismo ” , :   •   entrada menú lateral pantalla .   •   cardboard “ Ausentismo ” pa
# --------------------------------------------------
# Question: ¿Qué día hará mañana?
# Cosine Similarity: 0.630255937576294
# Chunk: mentación ,   verificación ) . gráfica descargar .
#
# 7   •   Datos evaluación : Redirige ficha evaluación .   •   evaluación : Redirige pestaña “ Evaluación ubicación ” .   •   medida control : Redirige pestaña “ Medidas preventivo / correctiva ” .   •   eliminar evaluación : permitir eliminar registro .
#
# pestaño Datos evaluación habilitar botón “ Cerrar evaluación ”   evaluación .    creado registro evaluación , habilitar pestaña :     •   Evaluación ubicación    •   Medidas preventivo / correct
# --------------------------------------------------
# Cosine Similarity: 0.6252517104148865
# Chunk: rivial , Tolerable , Moderado ,   Importante Intolerable ) . gráfica descargar .   medida tipo   medida   Gráfica dato circular determinar número medida   jerarquía control . gráfica descargar .   medida   Gráfica dato circular determinar número medida
#
# circular determinar número medida   gestión . gráfica descargar .   vencimiento   medida   Gráfica línea vencimiento fecha medida 6 mes ,   área tipo vencimiento , ( validación , implementación ,   verificación ) . gráfica descargar .
#
# 7   •
# --------------------------------------------------
# Cosine Similarity: 0.6080582141876221
# Chunk:  Víctor Andrade   contenido
#
# Sabentis plataforma gestión especializado ámbito seguridad salud   trabajo , adaptado tecnología modelo gestión   prevención riesgo .    módulo Identificación Evaluación Riesgos IER , permitir empresa   establecer procedimiento lógico valoración riesgo implícito proceso ,   permitir fijar estrategia gestión administrativo / operativo permitir controlar ,   reducir
#
# / operativo permitir controlar ,   reducir eliminar riesgo .
#
# 2 . identificación evaluación RIESGOS ( I
# --------------------------------------------------

# %% [markdown]
# ### Comprobación de embeddings con Bert

# %%
# Definir tres frases: dos similares y una distinta
phrase_1 = "El sol brilla intensamente en el cielo azul."
phrase_2 = "El cielo está despejado y el sol brilla."
phrase_3 = "El coche rojo está estacionado en la calle."

# Tokenizar y obtener embeddings para cada frase
phrases = [phrase_1, phrase_2, phrase_3]
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

def get_embedding(phrase):
    inputs = tokenizer(phrase, return_tensors='pt')
    outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).detach().numpy()

embeddings = [get_embedding(phrase) for phrase in phrases]

# Calcular distancias entre embeddings
dist_12 = np.linalg.norm(embeddings[0] - embeddings[1])
dist_13 = np.linalg.norm(embeddings[0] - embeddings[2])
dist_23 = np.linalg.norm(embeddings[1] - embeddings[2])

print(f"Distancia entre frases similares (1 y 2): {dist_12}")
print(f"Distancia entre frase distinta (1 y 3): {dist_13}")
print(f"Distancia entre frase distinta (2 y 3): {dist_23}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning:
#
# `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Distancia entre frases similares (1 y 2): 4.958994388580322
# Distancia entre frase distinta (1 y 3): 5.729472637176514
# Distancia entre frase distinta (2 y 3): 3.9385998249053955

# %% [markdown]
# Al analizar los resultados obtenidos al calcular las distancias entre los embeddings de las frases usando BERT, puedo hacer las siguientes observaciones:
#
#
# **Entre las frases 1 y 2**, que son similares, la distancia es de 4.958994388580322. Esto muestra que el modelo ha identificado cierta similitud semántica entre ambas, lo que es esperado dado que ambas frases describen un cielo despejado y el sol brillando.
#
#
# **Entre las frases 1 y 3**, que son conceptualmente diferentes, la distancia es mayor, de 5.729472637176514, indicando que el modelo reconoce adecuadamente que la frase sobre el coche rojo estacionado es distinta a la que habla del sol y el cielo.
#
#
# **Entre las frases 2 y 3**, el resultado es inesperado. La distancia de 3.9385998249053955 es la menor de todas, a pesar de que esperaría una gran diferencia semántica entre una frase sobre el clima y otra sobre un coche. Esto sugiere que tal vez el modelo no está captando completamente las diferencias temáticas que yo percibo.
#
#
# Estos resultados implican varias cosas:
#
#
# **Calibración del modelo:** Es posible que el modelo bert-base-uncased que estoy utilizando no esté completamente ajustado para captar todas las sutilezas del contexto en este experimento.
#
#
# **Sensibilidad y variabilidad del modelo:** Los modelos de lenguaje como BERT son sensibles al contexto y las palabras utilizadas, y pequeñas variaciones en el texto pueden generar cambios significativos en los embeddings. Además, la variabilidad en las representaciones podría estar afectando los resultados.
#
#
# En resumen, aunque los resultados muestran que el modelo tiene cierta capacidad para discernir similitudes y diferencias semánticas, también indican que puede haber limitaciones o aspectos peculiares en cómo se están calculando o interpretando estos embeddings. Sigo teniendo el "problema" que los chuncks comienzan por palabras ya empezadas.
